# %%
# %pip -q install duckdb

from pathlib import Path

import duckdb
import pandas as pd
from google.colab import drive

if not Path("/content/drive/MyDrive").exists():
    drive.mount("/content/drive")

BASE_DIR = Path("/content/drive/MyDrive/Language Detection")

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", None)
pd.set_option("display.width", None)
pd.set_option("display.expand_frame_repr", False)

con = duckdb.connect()

print("Ready")
# Out:
# Ready

# %%
PARQUET_PATH = BASE_DIR / "sessions_lang_transcript_2026-08-04_2026-08-05.parquet"

if not PARQUET_PATH.is_file():
    raise FileNotFoundError(PARQUET_PATH)

schema = con.execute(
    "DESCRIBE SELECT * FROM read_parquet(?)",
    [PARQUET_PATH.as_posix()],
).df()

result_2026_08_04 = con.execute(
    """
    SELECT
        *,
        len(transcript_segments) AS segment_count
    FROM read_parquet(?)
    WHERE
        transcript_segments IS NULL
        OR len(transcript_segments) = 0
    """,
    [PARQUET_PATH.as_posix()],
).df()

print("FILE:", PARQUET_PATH.name)
print(f"SIZE: {PARQUET_PATH.stat().st_size / 1024**2:.2f} MB")
print(f"ZERO-SEGMENT SESSIONS: {len(result_2026_08_04):,}")

print("\nSCHEMA")
display(schema)

print("\nALL ZERO-SEGMENT ROWS — ALL ORIGINAL COLUMNS")
display(result_2026_08_04)
# Out:
# FILE: sessions_lang_transcript_2026-08-04_2026-08-05.parquet
# SIZE: 4.03 MB
# ZERO-SEGMENT SESSIONS: 0
#
# SCHEMA
#            column_name                                                                                           column_type null   key default extra
# 0       gamesession_id                                                                                                BIGINT  YES  None    None  None
# 1              user_id                                                                                                BIGINT  YES  None    None  None
# 2            game_name                                                                                               VARCHAR  YES  None    None  None
# 3           model_type                                                                                               VARCHAR  YES  None    None  None
# ...

# %%
zero_segment_audit = con.execute(
    """
    SELECT
        gamesession_id,
        transcript_segments,
        len(transcript_segments) AS list_length,
        (
            SELECT COUNT(*)
            FROM UNNEST(transcript_segments)
        ) AS unnested_segment_count
    FROM read_parquet(?)
    WHERE
        transcript_segments IS NULL
        OR len(transcript_segments) = 0
    """,
    [PARQUET_PATH.as_posix()],
).df()

zero_segment_audit["verified_zero"] = (
    zero_segment_audit["list_length"].fillna(0).eq(0)
    & zero_segment_audit["unnested_segment_count"].eq(0)
)

display(zero_segment_audit)

assert zero_segment_audit["verified_zero"].all()

print("VERIFIED: every returned session contains 0 stored transcript segments.")
# Out:
# Empty DataFrame
# Columns: [gamesession_id, transcript_segments, list_length, unnested_segment_count, verified_zero]
# Index: []
# VERIFIED: every returned session contains 0 stored transcript segments.

# %%
PARQUET_PATH = BASE_DIR / "sessions_lang_transcript_2026-08-05_2026-08-06.parquet"

if not PARQUET_PATH.is_file():
    raise FileNotFoundError(PARQUET_PATH)

schema = con.execute(
    "DESCRIBE SELECT * FROM read_parquet(?)",
    [PARQUET_PATH.as_posix()],
).df()

result_2026_08_05 = con.execute(
    """
    SELECT
        *,
        len(transcript_segments) AS segment_count
    FROM read_parquet(?)
    WHERE
        transcript_segments IS NULL
        OR len(transcript_segments) = 0
    """,
    [PARQUET_PATH.as_posix()],
).df()

print("FILE:", PARQUET_PATH.name)
print(f"SIZE: {PARQUET_PATH.stat().st_size / 1024**2:.2f} MB")
print(f"ZERO-SEGMENT SESSIONS: {len(result_2026_08_05):,}")

print("\nSCHEMA")
display(schema)

print("\nALL ZERO-SEGMENT ROWS — ALL ORIGINAL COLUMNS")
display(result_2026_08_05)
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FILE: sessions_lang_transcript_2026-08-05_2026-08-06.parquet
# SIZE: 79.44 MB
# ZERO-SEGMENT SESSIONS: 2
#
# SCHEMA
#            column_name                                                                                           column_type null   key default extra
# 0       gamesession_id                                                                                                BIGINT  YES  None    None  None
# 1              user_id                                                                                                BIGINT  YES  None    None  None
# 2            game_name                                                                                               VARCHAR  YES  None    None  None
# 3           model_type                                                                                               VARCHAR  YES  None    None  None
# ...

# %%
zero_segment_audit = con.execute(
    """
    SELECT
        gamesession_id,
        transcript_segments,
        len(transcript_segments) AS list_length,
        (
            SELECT COUNT(*)
            FROM UNNEST(transcript_segments)
        ) AS unnested_segment_count
    FROM read_parquet(?)
    WHERE
        transcript_segments IS NULL
        OR len(transcript_segments) = 0
    """,
    [PARQUET_PATH.as_posix()],
).df()

zero_segment_audit["verified_zero"] = (
    zero_segment_audit["list_length"].fillna(0).eq(0)
    & zero_segment_audit["unnested_segment_count"].eq(0)
)

display(zero_segment_audit)

assert zero_segment_audit["verified_zero"].all()

print("VERIFIED: every returned session contains 0 stored transcript segments.")
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
#    gamesession_id transcript_segments  list_length  unnested_segment_count  verified_zero
# 0       140621798                  []            0                       0           True
# 1       140637851                  []            0                       0           True
# VERIFIED: every returned session contains 0 stored transcript segments.

# %%
PARQUET_PATH = BASE_DIR / "sessions_lang_transcript_2026-08-06_2026-08-07.parquet"

if not PARQUET_PATH.is_file():
    raise FileNotFoundError(PARQUET_PATH)

schema = con.execute(
    "DESCRIBE SELECT * FROM read_parquet(?)",
    [PARQUET_PATH.as_posix()],
).df()

result_2026_08_06 = con.execute(
    """
    SELECT
        *,
        len(transcript_segments) AS segment_count
    FROM read_parquet(?)
    WHERE
        transcript_segments IS NULL
        OR len(transcript_segments) = 0
    """,
    [PARQUET_PATH.as_posix()],
).df()

print("FILE:", PARQUET_PATH.name)
print(f"SIZE: {PARQUET_PATH.stat().st_size / 1024**2:.2f} MB")
print(f"ZERO-SEGMENT SESSIONS: {len(result_2026_08_06):,}")

print("\nSCHEMA")
display(schema)

print("\nALL ZERO-SEGMENT ROWS — ALL ORIGINAL COLUMNS")
display(result_2026_08_06)
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FILE: sessions_lang_transcript_2026-08-06_2026-08-07.parquet
# SIZE: 443.52 MB
# ZERO-SEGMENT SESSIONS: 10
#
# SCHEMA
#            column_name                                                                                           column_type null   key default extra
# 0       gamesession_id                                                                                                BIGINT  YES  None    None  None
# 1              user_id                                                                                                BIGINT  YES  None    None  None
# 2            game_name                                                                                               VARCHAR  YES  None    None  None
# 3           model_type                                                                                               VARCHAR  YES  None    None  None
# ...

# %%
zero_segment_audit = con.execute(
    """
    SELECT
        gamesession_id,
        transcript_segments,
        len(transcript_segments) AS list_length,
        (
            SELECT COUNT(*)
            FROM UNNEST(transcript_segments)
        ) AS unnested_segment_count
    FROM read_parquet(?)
    WHERE
        transcript_segments IS NULL
        OR len(transcript_segments) = 0
    """,
    [PARQUET_PATH.as_posix()],
).df()

zero_segment_audit["verified_zero"] = (
    zero_segment_audit["list_length"].fillna(0).eq(0)
    & zero_segment_audit["unnested_segment_count"].eq(0)
)

display(zero_segment_audit)

assert zero_segment_audit["verified_zero"].all()

print("VERIFIED: every returned session contains 0 stored transcript segments.")
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
#    gamesession_id transcript_segments  list_length  unnested_segment_count  verified_zero
# 0       140651910                  []            0                       0           True
# 1       140672890                  []            0                       0           True
# 2       140667401                  []            0                       0           True
# 3       140658750                  []            0                       0           True
# 4       140654392                  []            0                       0           True
# 5       140653109                  []            0                       0           True
# 6       140646535                  []            0                       0           True
# 7       140649636                  []            0                       0           True
# ...

# %%
PARQUET_PATH = BASE_DIR / "sessions_lang_transcript_2026-08-10_2026-08-11.parquet"

if not PARQUET_PATH.is_file():
    raise FileNotFoundError(PARQUET_PATH)

schema = con.execute(
    "DESCRIBE SELECT * FROM read_parquet(?)",
    [PARQUET_PATH.as_posix()],
).df()

result_2026_08_10 = con.execute(
    """
    SELECT
        *,
        len(transcript_segments) AS segment_count
    FROM read_parquet(?)
    WHERE
        transcript_segments IS NULL
        OR len(transcript_segments) = 0
    """,
    [PARQUET_PATH.as_posix()],
).df()

print("FILE:", PARQUET_PATH.name)
print(f"SIZE: {PARQUET_PATH.stat().st_size / 1024**2:.2f} MB")
print(f"ZERO-SEGMENT SESSIONS: {len(result_2026_08_10):,}")

print("\nSCHEMA")
display(schema)

print("\nALL ZERO-SEGMENT ROWS — ALL ORIGINAL COLUMNS")
display(result_2026_08_10)
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FILE: sessions_lang_transcript_2026-08-10_2026-08-11.parquet
# SIZE: 452.27 MB
# ZERO-SEGMENT SESSIONS: 7
#
# SCHEMA
#            column_name                                                                                           column_type null   key default extra
# 0       gamesession_id                                                                                                BIGINT  YES  None    None  None
# 1              user_id                                                                                                BIGINT  YES  None    None  None
# 2            game_name                                                                                               VARCHAR  YES  None    None  None
# 3           model_type                                                                                               VARCHAR  YES  None    None  None
# ...

# %%
zero_segment_audit = con.execute(
    """
    SELECT
        gamesession_id,
        transcript_segments,
        len(transcript_segments) AS list_length,
        (
            SELECT COUNT(*)
            FROM UNNEST(transcript_segments)
        ) AS unnested_segment_count
    FROM read_parquet(?)
    WHERE
        transcript_segments IS NULL
        OR len(transcript_segments) = 0
    """,
    [PARQUET_PATH.as_posix()],
).df()

zero_segment_audit["verified_zero"] = (
    zero_segment_audit["list_length"].fillna(0).eq(0)
    & zero_segment_audit["unnested_segment_count"].eq(0)
)

display(zero_segment_audit)

assert zero_segment_audit["verified_zero"].all()

print("VERIFIED: every returned session contains 0 stored transcript segments.")
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
#    gamesession_id transcript_segments  list_length  unnested_segment_count  verified_zero
# 0       140808550                  []            0                       0           True
# 1       140793686                  []            0                       0           True
# 2       140804320                  []            0                       0           True
# 3       140786095                  []            0                       0           True
# 4       140786298                  []            0                       0           True
# 5       140792635                  []            0                       0           True
# 6       140788180                  []            0                       0           True
# VERIFIED: every returned session contains 0 stored transcript segments.

# %%
PARQUET_PATH = BASE_DIR / "sessions_lang_transcript_2026-08-13_2026-08-14.parquet"

if not PARQUET_PATH.is_file():
    raise FileNotFoundError(PARQUET_PATH)

schema = con.execute(
    "DESCRIBE SELECT * FROM read_parquet(?)",
    [PARQUET_PATH.as_posix()],
).df()

result_2026_08_13 = con.execute(
    """
    SELECT
        *,
        len(transcript_segments) AS segment_count
    FROM read_parquet(?)
    WHERE
        transcript_segments IS NULL
        OR len(transcript_segments) = 0
    """,
    [PARQUET_PATH.as_posix()],
).df()

print("FILE:", PARQUET_PATH.name)
print(f"SIZE: {PARQUET_PATH.stat().st_size / 1024**2:.2f} MB")
print(f"ZERO-SEGMENT SESSIONS: {len(result_2026_08_13):,}")

print("\nSCHEMA")
display(schema)

print("\nALL ZERO-SEGMENT ROWS — ALL ORIGINAL COLUMNS")
display(result_2026_08_13)
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FILE: sessions_lang_transcript_2026-08-13_2026-08-14.parquet
# SIZE: 455.47 MB
# ZERO-SEGMENT SESSIONS: 11
#
# SCHEMA
#            column_name                                                                                           column_type null   key default extra
# 0       gamesession_id                                                                                                BIGINT  YES  None    None  None
# 1              user_id                                                                                                BIGINT  YES  None    None  None
# 2            game_name                                                                                               VARCHAR  YES  None    None  None
# 3           model_type                                                                                               VARCHAR  YES  None    None  None
# ...

# %%
zero_segment_audit = con.execute(
    """
    SELECT
        gamesession_id,
        transcript_segments,
        len(transcript_segments) AS list_length,
        (
            SELECT COUNT(*)
            FROM UNNEST(transcript_segments)
        ) AS unnested_segment_count
    FROM read_parquet(?)
    WHERE
        transcript_segments IS NULL
        OR len(transcript_segments) = 0
    """,
    [PARQUET_PATH.as_posix()],
).df()

zero_segment_audit["verified_zero"] = (
    zero_segment_audit["list_length"].fillna(0).eq(0)
    & zero_segment_audit["unnested_segment_count"].eq(0)
)

display(zero_segment_audit)

assert zero_segment_audit["verified_zero"].all()

print("VERIFIED: every returned session contains 0 stored transcript segments.")
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
#     gamesession_id transcript_segments  list_length  unnested_segment_count  verified_zero
# 0        140887514                  []            0                       0           True
# 1        140890576                  []            0                       0           True
# 2        140893252                  []            0                       0           True
# 3        140908285                  []            0                       0           True
# 4        140889688                  []            0                       0           True
# 5        140889600                  []            0                       0           True
# 6        140888503                  []            0                       0           True
# 7        140908714                  []            0                       0           True
# ...

# %%
PARQUET_PATH = BASE_DIR / "sessions_lang_transcript_2026-08-07_2026-08-08.parquet"

if not PARQUET_PATH.is_file():
    raise FileNotFoundError(PARQUET_PATH)

schema = con.execute(
    "DESCRIBE SELECT * FROM read_parquet(?)",
    [PARQUET_PATH.as_posix()],
).df()

result_2026_08_07 = con.execute(
    """
    SELECT
        *,
        len(transcript_segments) AS segment_count
    FROM read_parquet(?)
    WHERE
        transcript_segments IS NULL
        OR len(transcript_segments) = 0
    """,
    [PARQUET_PATH.as_posix()],
).df()

print("FILE:", PARQUET_PATH.name)
print(f"SIZE: {PARQUET_PATH.stat().st_size / 1024**2:.2f} MB")
print(f"ZERO-SEGMENT SESSIONS: {len(result_2026_08_07):,}")

print("\nSCHEMA")
display(schema)

print("\nALL ZERO-SEGMENT ROWS — ALL ORIGINAL COLUMNS")
display(result_2026_08_07)
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FILE: sessions_lang_transcript_2026-08-07_2026-08-08.parquet
# SIZE: 464.40 MB
# ZERO-SEGMENT SESSIONS: 18
#
# SCHEMA
#            column_name                                                                                           column_type null   key default extra
# 0       gamesession_id                                                                                                BIGINT  YES  None    None  None
# 1              user_id                                                                                                BIGINT  YES  None    None  None
# 2            game_name                                                                                               VARCHAR  YES  None    None  None
# 3           model_type                                                                                               VARCHAR  YES  None    None  None
# ...

# %%
zero_segment_audit = con.execute(
    """
    SELECT
        gamesession_id,
        transcript_segments,
        len(transcript_segments) AS list_length,
        (
            SELECT COUNT(*)
            FROM UNNEST(transcript_segments)
        ) AS unnested_segment_count
    FROM read_parquet(?)
    WHERE
        transcript_segments IS NULL
        OR len(transcript_segments) = 0
    """,
    [PARQUET_PATH.as_posix()],
).df()

zero_segment_audit["verified_zero"] = (
    zero_segment_audit["list_length"].fillna(0).eq(0)
    & zero_segment_audit["unnested_segment_count"].eq(0)
)

display(zero_segment_audit)

assert zero_segment_audit["verified_zero"].all()

print("VERIFIED: every returned session contains 0 stored transcript segments.")
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
#     gamesession_id transcript_segments  list_length  unnested_segment_count  verified_zero
# 0        140686524                  []            0                       0           True
# 1        140707332                  []            0                       0           True
# 2        140684877                  []            0                       0           True
# 3        140704799                  []            0                       0           True
# 4        140678191                  []            0                       0           True
# 5        140684243                  []            0                       0           True
# 6        140684713                  []            0                       0           True
# 7        140705326                  []            0                       0           True
# ...

# %%
PARQUET_PATH = BASE_DIR / "sessions_lang_transcript_2026-08-12_2026-08-13.parquet"

if not PARQUET_PATH.is_file():
    raise FileNotFoundError(PARQUET_PATH)

schema = con.execute(
    "DESCRIBE SELECT * FROM read_parquet(?)",
    [PARQUET_PATH.as_posix()],
).df()

result_2026_08_12 = con.execute(
    """
    SELECT
        *,
        len(transcript_segments) AS segment_count
    FROM read_parquet(?)
    WHERE
        transcript_segments IS NULL
        OR len(transcript_segments) = 0
    """,
    [PARQUET_PATH.as_posix()],
).df()

print("FILE:", PARQUET_PATH.name)
print(f"SIZE: {PARQUET_PATH.stat().st_size / 1024**2:.2f} MB")
print(f"ZERO-SEGMENT SESSIONS: {len(result_2026_08_12):,}")

print("\nSCHEMA")
display(schema)

print("\nALL ZERO-SEGMENT ROWS — ALL ORIGINAL COLUMNS")
display(result_2026_08_12)
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FILE: sessions_lang_transcript_2026-08-12_2026-08-13.parquet
# SIZE: 469.43 MB
# ZERO-SEGMENT SESSIONS: 11
#
# SCHEMA
#            column_name                                                                                           column_type null   key default extra
# 0       gamesession_id                                                                                                BIGINT  YES  None    None  None
# 1              user_id                                                                                                BIGINT  YES  None    None  None
# 2            game_name                                                                                               VARCHAR  YES  None    None  None
# 3           model_type                                                                                               VARCHAR  YES  None    None  None
# ...

# %%
zero_segment_audit = con.execute(
    """
    SELECT
        gamesession_id,
        transcript_segments,
        len(transcript_segments) AS list_length,
        (
            SELECT COUNT(*)
            FROM UNNEST(transcript_segments)
        ) AS unnested_segment_count
    FROM read_parquet(?)
    WHERE
        transcript_segments IS NULL
        OR len(transcript_segments) = 0
    """,
    [PARQUET_PATH.as_posix()],
).df()

zero_segment_audit["verified_zero"] = (
    zero_segment_audit["list_length"].fillna(0).eq(0)
    & zero_segment_audit["unnested_segment_count"].eq(0)
)

display(zero_segment_audit)

assert zero_segment_audit["verified_zero"].all()

print("VERIFIED: every returned session contains 0 stored transcript segments.")
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
#     gamesession_id transcript_segments  list_length  unnested_segment_count  verified_zero
# 0        140866876                  []            0                       0           True
# 1        140859949                  []            0                       0           True
# 2        140882651                  []            0                       0           True
# 3        140855586                  []            0                       0           True
# 4        140872944                  []            0                       0           True
# 5        140878208                  []            0                       0           True
# 6        140851311                  []            0                       0           True
# 7        140846927                  []            0                       0           True
# ...

# %%
PARQUET_PATH = BASE_DIR / "sessions_lang_transcript_2026-08-11_2026-08-12.parquet"

if not PARQUET_PATH.is_file():
    raise FileNotFoundError(PARQUET_PATH)

schema = con.execute(
    "DESCRIBE SELECT * FROM read_parquet(?)",
    [PARQUET_PATH.as_posix()],
).df()

result_2026_08_11 = con.execute(
    """
    SELECT
        *,
        len(transcript_segments) AS segment_count
    FROM read_parquet(?)
    WHERE
        transcript_segments IS NULL
        OR len(transcript_segments) = 0
    """,
    [PARQUET_PATH.as_posix()],
).df()

print("FILE:", PARQUET_PATH.name)
print(f"SIZE: {PARQUET_PATH.stat().st_size / 1024**2:.2f} MB")
print(f"ZERO-SEGMENT SESSIONS: {len(result_2026_08_11):,}")

print("\nSCHEMA")
display(schema)

print("\nALL ZERO-SEGMENT ROWS — ALL ORIGINAL COLUMNS")
display(result_2026_08_11)
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FILE: sessions_lang_transcript_2026-08-11_2026-08-12.parquet
# SIZE: 472.56 MB
# ZERO-SEGMENT SESSIONS: 13
#
# SCHEMA
#            column_name                                                                                           column_type null   key default extra
# 0       gamesession_id                                                                                                BIGINT  YES  None    None  None
# 1              user_id                                                                                                BIGINT  YES  None    None  None
# 2            game_name                                                                                               VARCHAR  YES  None    None  None
# 3           model_type                                                                                               VARCHAR  YES  None    None  None
# ...

# %%
zero_segment_audit = con.execute(
    """
    SELECT
        gamesession_id,
        transcript_segments,
        len(transcript_segments) AS list_length,
        (
            SELECT COUNT(*)
            FROM UNNEST(transcript_segments)
        ) AS unnested_segment_count
    FROM read_parquet(?)
    WHERE
        transcript_segments IS NULL
        OR len(transcript_segments) = 0
    """,
    [PARQUET_PATH.as_posix()],
).df()

zero_segment_audit["verified_zero"] = (
    zero_segment_audit["list_length"].fillna(0).eq(0)
    & zero_segment_audit["unnested_segment_count"].eq(0)
)

display(zero_segment_audit)

assert zero_segment_audit["verified_zero"].all()

print("VERIFIED: every returned session contains 0 stored transcript segments.")
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
#     gamesession_id transcript_segments  list_length  unnested_segment_count  verified_zero
# 0        140790230                  []            0                       0           True
# 1        140825843                  []            0                       0           True
# 2        140818559                  []            0                       0           True
# 3        140825185                  []            0                       0           True
# 4        140824597                  []            0                       0           True
# 5        140825768                  []            0                       0           True
# 6        140846032                  []            0                       0           True
# 7        140813646                  []            0                       0           True
# ...

# %%
PARQUET_PATH = BASE_DIR / "sessions_lang_transcript_2026-08-09_2026-08-10.parquet"

if not PARQUET_PATH.is_file():
    raise FileNotFoundError(PARQUET_PATH)

schema = con.execute(
    "DESCRIBE SELECT * FROM read_parquet(?)",
    [PARQUET_PATH.as_posix()],
).df()

result_2026_08_09 = con.execute(
    """
    SELECT
        *,
        len(transcript_segments) AS segment_count
    FROM read_parquet(?)
    WHERE
        transcript_segments IS NULL
        OR len(transcript_segments) = 0
    """,
    [PARQUET_PATH.as_posix()],
).df()

print("FILE:", PARQUET_PATH.name)
print(f"SIZE: {PARQUET_PATH.stat().st_size / 1024**2:.2f} MB")
print(f"ZERO-SEGMENT SESSIONS: {len(result_2026_08_09):,}")

print("\nSCHEMA")
display(schema)

print("\nALL ZERO-SEGMENT ROWS — ALL ORIGINAL COLUMNS")
display(result_2026_08_09)
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FILE: sessions_lang_transcript_2026-08-09_2026-08-10.parquet
# SIZE: 495.19 MB
# ZERO-SEGMENT SESSIONS: 17
#
# SCHEMA
#            column_name                                                                                           column_type null   key default extra
# 0       gamesession_id                                                                                                BIGINT  YES  None    None  None
# 1              user_id                                                                                                BIGINT  YES  None    None  None
# 2            game_name                                                                                               VARCHAR  YES  None    None  None
# 3           model_type                                                                                               VARCHAR  YES  None    None  None
# ...

# %%
zero_segment_audit = con.execute(
    """
    SELECT
        gamesession_id,
        transcript_segments,
        len(transcript_segments) AS list_length,
        (
            SELECT COUNT(*)
            FROM UNNEST(transcript_segments)
        ) AS unnested_segment_count
    FROM read_parquet(?)
    WHERE
        transcript_segments IS NULL
        OR len(transcript_segments) = 0
    """,
    [PARQUET_PATH.as_posix()],
).df()

zero_segment_audit["verified_zero"] = (
    zero_segment_audit["list_length"].fillna(0).eq(0)
    & zero_segment_audit["unnested_segment_count"].eq(0)
)

display(zero_segment_audit)

assert zero_segment_audit["verified_zero"].all()

print("VERIFIED: every returned session contains 0 stored transcript segments.")
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
#     gamesession_id transcript_segments  list_length  unnested_segment_count  verified_zero
# 0        140765075                  []            0                       0           True
# 1        140763912                  []            0                       0           True
# 2        140756532                  []            0                       0           True
# 3        140756195                  []            0                       0           True
# 4        140748963                  []            0                       0           True
# 5        140758645                  []            0                       0           True
# 6        140779230                  []            0                       0           True
# 7        140779165                  []            0                       0           True
# ...

# %%
PARQUET_PATH = BASE_DIR / "sessions_lang_transcript_2026-08-08_2026-08-09.parquet"

if not PARQUET_PATH.is_file():
    raise FileNotFoundError(PARQUET_PATH)

schema = con.execute(
    "DESCRIBE SELECT * FROM read_parquet(?)",
    [PARQUET_PATH.as_posix()],
).df()

result_2026_08_08 = con.execute(
    """
    SELECT
        *,
        len(transcript_segments) AS segment_count
    FROM read_parquet(?)
    WHERE
        transcript_segments IS NULL
        OR len(transcript_segments) = 0
    """,
    [PARQUET_PATH.as_posix()],
).df()

print("FILE:", PARQUET_PATH.name)
print(f"SIZE: {PARQUET_PATH.stat().st_size / 1024**2:.2f} MB")
print(f"ZERO-SEGMENT SESSIONS: {len(result_2026_08_08):,}")

print("\nSCHEMA")
display(schema)

print("\nALL ZERO-SEGMENT ROWS — ALL ORIGINAL COLUMNS")
display(result_2026_08_08)
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FILE: sessions_lang_transcript_2026-08-08_2026-08-09.parquet
# SIZE: 503.78 MB
# ZERO-SEGMENT SESSIONS: 7
#
# SCHEMA
#            column_name                                                                                           column_type null   key default extra
# 0       gamesession_id                                                                                                BIGINT  YES  None    None  None
# 1              user_id                                                                                                BIGINT  YES  None    None  None
# 2            game_name                                                                                               VARCHAR  YES  None    None  None
# 3           model_type                                                                                               VARCHAR  YES  None    None  None
# ...

# %%
zero_segment_audit = con.execute(
    """
    SELECT
        gamesession_id,
        transcript_segments,
        len(transcript_segments) AS list_length,
        (
            SELECT COUNT(*)
            FROM UNNEST(transcript_segments)
        ) AS unnested_segment_count
    FROM read_parquet(?)
    WHERE
        transcript_segments IS NULL
        OR len(transcript_segments) = 0
    """,
    [PARQUET_PATH.as_posix()],
).df()

zero_segment_audit["verified_zero"] = (
    zero_segment_audit["list_length"].fillna(0).eq(0)
    & zero_segment_audit["unnested_segment_count"].eq(0)
)

display(zero_segment_audit)

assert zero_segment_audit["verified_zero"].all()

print("VERIFIED: every returned session contains 0 stored transcript segments.")
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
#    gamesession_id transcript_segments  list_length  unnested_segment_count  verified_zero
# 0       140741370                  []            0                       0           True
# 1       140743225                  []            0                       0           True
# 2       140744058                  []            0                       0           True
# 3       140748508                  []            0                       0           True
# 4       140733354                  []            0                       0           True
# 5       140727372                  []            0                       0           True
# 6       140741712                  []            0                       0           True
# VERIFIED: every returned session contains 0 stored transcript segments.
